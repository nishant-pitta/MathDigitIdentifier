# %% [markdown]
# <a href="https://colab.research.google.com/github/nishant-pitta/MathDigitIdentifier/blob/main/MathSymbolIdentifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn #Module which contains all the necessary tools for building an ANN.
import torch.nn.functional as F #Module wich contains all the necessary functions used in a ANN.
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
#Download train and test data.
transform = transforms.ToTensor() #Converts a numpy.ndarray to tensor.
train_data = datasets.MNIST(root='../Data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='../Data', train=False, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../Data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 109831171.29it/s]
# Extracting ../Data/MNIST/raw/train-images-idx3-ubyte.gz to ../Data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../Data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 82461330.04it/s]
# Extracting ../Data/MNIST/raw/train-labels-idx1-ubyte.gz to ../Data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../Data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 37220232.48it/s]
# Extracting ../Data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../Data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../Data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 1241238.52it/s]
# Extracting ../Data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../Data/MNIST/raw

# %%
#We convert train and test data to a set of batches.
#We shuffle the training data because we want a uniform distribution among classes in each batch.
train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

# %%
#Plot a random image from the train data.
np.random.seed(99)
random_image_n = np.random.randint(low=0, high=len(train_data))
plt.imshow(train_data[random_image_n][0].reshape(train_data[random_image_n][0].shape[1],train_data[random_image_n][0].shape[1]), cmap='gist_yarg_r')
plt.title(label=print(f'Image Label: {train_data[random_image_n][1]}'));
# Out:
# Image Label: 3

# %%
#Set up a toy-CNN and feed to it the above random image.
torch.manual_seed(99) #for reproducibility.
random_image = train_data[random_image_n][0].reshape(1,1,28,28) #Create a batch from the above random image
feature_maps1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=3, stride=1)(random_image)
act_feature_maps1 = F.relu(feature_maps1)
pooled_feature_maps1 = F.max_pool2d(act_feature_maps1,2,2)
feature_maps2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=3, stride=1)(pooled_feature_maps1)
act_feature_maps2 = F.relu(feature_maps2)
pooled_feature_maps2 = F.max_pool2d(act_feature_maps2,2,2)

# %%
#Feature and activation map visualization.
def layerviz(covnetlayer,cols,rows=1,cmap='jet'):
    fig=plt.figure(figsize=(16, 16))
    if covnetlayer.shape[1] != cols*rows: 
      return print('The total number of plot s images exceeds the available image number in this layer...')
    else:
      for i in range(1, cols*rows +1):
        img = covnetlayer[0,i-1,:,:]
        fig.add_subplot(rows, cols, i)
        plt.title("Map: {}".format(i))
        plotable_image = img.reshape(covnetlayer.shape[2],covnetlayer.shape[3])
        plt.imshow(plotable_image.detach().numpy(), cmap=cmap)
      return plt.show()

# %%
layerviz(feature_maps1,6,1)

# %%
layerviz(act_feature_maps1,6,1)

# %%
layerviz(pooled_feature_maps1,6,1)

# %%
layerviz(feature_maps2,12)

# %%
layerviz(act_feature_maps2,12)

# %%
layerviz(pooled_feature_maps2,12)

# %%
#Build the model.
class ConvNet(nn.Module): # Class ConvNet inherits all the methods and properties from the class "nn.Module".
    
    def __init__(self): #The 'self' variable represents the instance and the '__init__' function is the constructor.
        super().__init__() #The super() function is used to give access to methods and properties of a parent or sibling class. Returns an object that represents the parent class.
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=3, stride=1)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(in_features=12*5*5, out_features=200)
        self.fc2 = nn.Linear(in_features=200, out_features=100)
        self.fc3 = nn.Linear(in_features=100, out_features=10)
   
    def forward(self,X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X,2,2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X,2,2)
        X = X.view(-1,12*5*5)# --------------> Image Flatenning (Reshaping from a 12 images of 5x5 to a column tensor of ... )
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        return F.log_softmax(self.fc3(X),dim=1)

# %%
#Set up the loss function and the optimizer.
torch.manual_seed(98)
model = ConvNet() #Create an istance of the ConvNet class.
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)

# %%
#Calculate the total number of weights and biases.
c=1
weights = 0
biases = 0
for par in model.parameters():
  if c%2 !=0: 
    print('Layer number {} has {} weights '.format(c//2+1,par.numel()))
    weights+=par.numel()
  else: 
    print('Layer number {} has {} biases\n'.format(c//2,par.numel()))
    biases+=par.numel()
  c+=1
print(f'The CNN has a total of {weights+biases} parameters ({weights} weights and {biases} biases)')
# Out:
# Layer number 1 has 54 weights
# Layer number 1 has 6 biases
#
# Layer number 2 has 648 weights
# Layer number 2 has 12 biases
#
# Layer number 3 has 60000 weights
# Layer number 3 has 200 biases
#
# Layer number 4 has 20000 weights
# Layer number 4 has 100 biases
#
# Layer number 5 has 1000 weights
# Layer number 5 has 10 biases
#
# The CNN has a total of 82030 parameters (81702 weights and 328 biases)

# %%
#Train the model.
import time
import math
starting_time = time.time()

#We must track the loss and the accuracy during the training phase.
training_loss_per_epoch = []
training_loss_per_batch = []
val_loss_per_epoch = []

training_correct_predictions = []
val_acc = []

epochs = 5
report_every_x_batches = 600
for epoch in range(epochs):

    #Training Data
    for batch, (X_train,y_train) in enumerate(train_loader):

        batch +=1 #So the number of the first batch is equal to one.
        y_pred = model(X_train)
        loss = loss_function(y_pred,y_train)

        #y_pred_vector = torch.max(y_pred, dim=1)[1]
        #corr_preds = (y_pred_vector==y_train).sum()
        #training_correct_predictions.append()
    
        #Backpropagation.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #Report while training.
        if batch%report_every_x_batches == 0: 
          print(f'We are in epoch number {epoch+1}, in batch {batch}, and the loss is {loss}')
          training_loss_per_batch.append(loss)
    training_loss_per_epoch.append(loss)


    #Validation Data.
    with torch.no_grad():
        for batch, (X_test,y_test) in enumerate(test_loader):
            y_pred_val = model(X_test)
    loss_val = loss_function(y_pred_val,y_test)
    val_loss_per_epoch.append(loss_val)
    print(f'-----In epoch {epoch+1}, loss in validation data is {loss_val}-----')

total_training_time = (time.time() - starting_time)/3600
hours = int(math.modf(total_training_time)[1])
minutes = round(math.modf(total_training_time)[0]*60,3)
print('The total training time is {} hours and {:.2} minutes'.format(hours,minutes))
# Out:
# We are in epoch number 1, in batch 600, and the loss is 0.0981827825307846
# We are in epoch number 1, in batch 1200, and the loss is 0.19364959001541138
# We are in epoch number 1, in batch 1800, and the loss is 0.30300962924957275
# We are in epoch number 1, in batch 2400, and the loss is 0.021611910313367844
# We are in epoch number 1, in batch 3000, and the loss is 0.22075355052947998
# We are in epoch number 1, in batch 3600, and the loss is 0.046502649784088135
# We are in epoch number 1, in batch 4200, and the loss is 0.05712350085377693
# We are in epoch number 1, in batch 4800, and the loss is 0.2629414200782776
# We are in epoch number 1, in batch 5400, and the loss is 0.0007019313052296638
# We are in epoch number 1, in batch 6000, and the loss is 0.008985595777630806
# -----In epoch 1, loss in validation data is 0.0020518540404736996-----
# We are in epoch number 2, in batch 600, and the loss is 0.04887670278549194
# We are in epoch number 2, in batch 1200, and the loss is 0.06848126649856567
# We are in epoch number 2, in batch 1800, and the loss is 0.0014111108612269163
# We are in epoch number 2, in batch 2400, and the loss is 0.00035383907379582524
# We are in epoch number 2, in batch 3000, and the loss is 0.0030295406468212605
# We are in epoch number 2, in batch 3600, and the loss is 0.0032307300716638565
# We are in epoch number 2, in batch 4200, and the loss is 0.005866486579179764
# We are in epoch number 2, in batch 4800, and the loss is 0.0336482897400856
# We are in epoch number 2, in batch 5400, and the loss is 0.00434890715405345
# We are in epoch number 2, in batch 6000, and the loss is 0.001995441969484091
# -----In epoch 2, loss in validation data is 0.000722539029084146-----
# We are in epoch number 3, in batch 600, and the loss is 0.07025715708732605
# We are in epoch number 3, in batch 1200, and the loss is 0.0013580783270299435
# We are in epoch number 3, in batch 1800, and the loss is 0.000695224036462605
# We are in epoch number 3, in batch 2400, and the loss is 0.0003443221212364733
# We are in epoch number 3, in batch 3000, and the loss is 0.018588298931717873
# We are in epoch number 3, in batch 3600, and the loss is 0.002528801327571273
# We are in epoch number 3, in batch 4200, and the loss is 0.0004731512162834406
# We are in epoch number 3, in batch 4800, and the loss is 0.00026896625058725476
# We are in epoch number 3, in batch 5400, and the loss is 0.010806879960000515
# We are in epoch number 3, in batch 6000, and the loss is 0.06824089586734772
# -----In epoch 3, loss in validation data is 0.015201049856841564-----
# We are in epoch number 4, in batch 600, and the loss is 0.08302367478609085
# We are in epoch number 4, in batch 1200, and the loss is 0.00119306449778378
# We are in epoch number 4, in batch 1800, and the loss is 0.0015895934775471687
# We are in epoch number 4, in batch 2400, and the loss is 0.003915748558938503
# We are in epoch number 4, in batch 3000, and the loss is 0.0023086820729076862
# We are in epoch number 4, in batch 3600, and the loss is 0.019113248214125633
# We are in epoch number 4, in batch 4200, and the loss is 0.002050256822258234
# We are in epoch number 4, in batch 4800, and the loss is 2.8013957944494905e-06
# We are in epoch number 4, in batch 5400, and the loss is 0.005983828566968441
# We are in epoch number 4, in batch 6000, and the loss is 0.02443951927125454
# -----In epoch 4, loss in validation data is 0.00011511905177030712-----
# We are in epoch number 5, in batch 600, and the loss is 0.005398943554610014
# We are in epoch number 5, in batch 1200, and the loss is 0.4623299539089203
# We are in epoch number 5, in batch 1800, and the loss is 0.00035626368480734527
# We are in epoch number 5, in batch 2400, and the loss is 0.053593914955854416
# We are in epoch number 5, in batch 3000, and the loss is 0.00033788688597269356
# We are in epoch number 5, in batch 3600, and the loss is 0.0013101157965138555
# We are in epoch number 5, in batch 4200, and the loss is 0.0005885801510885358
# We are in epoch number 5, in batch 4800, and the loss is 0.014844441786408424
# We are in epoch number 5, in batch 5400, and the loss is 0.008394798263907433
# We are in epoch number 5, in batch 6000, and the loss is 0.0006065862835384905
# -----In epoch 5, loss in validation data is 0.00036558398278430104-----
# The total training time is 0 hours and 3.2 minutes

# %%
#Feed all the test data in to the model.
test_data_all = DataLoader(test_data,batch_size=10000,shuffle=False)
pred_propabilities,pred_classes = None,None
with torch.no_grad():
    correct_guesses = 0
    for test_images, test_image_labels in test_data_all:
        pred_propabilities = model(test_images)
        pred_classes = torch.max(pred_propabilities, dim=1)[1]
        correct_guesses+=(pred_classes==test_image_labels).sum()

# %%
#Accuracy %
correct_guesses.item()*100/10000
# Out:
# 99.09

# %%
#Install torchviz
# !pip install torchviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchviz) (2.0.1+cu118)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from torchviz) (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchviz) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchviz) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchviz) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchviz) (1.3.0)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4131 sha256=9c9c02659d0389dba4248f5c3a1f821ec1ba8a03cee863f08606229546e33dba
#   Stored in directory: /root/.cache/pip/wheels/4c/97/88/a02973217949e0db0c9f4346d154085f4725f99c4f15a87094
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2

# %%
#Model visualization
from torchviz import make_dot
from graphviz import Graph
x = torch.zeros(1, 1, 28, 28, dtype=torch.float, requires_grad=False)
out = model(x)
arch = make_dot(out) # plot graph of variable, not of a nn.Module

arch.format = 'png'
arch.render( )
# Out:
# 'Digraph.gv.png'
